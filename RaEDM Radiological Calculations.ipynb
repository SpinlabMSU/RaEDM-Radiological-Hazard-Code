# %% [markdown]
# ## Radiological Hazard Estimates for the Radium EDM Project 60 kV Upgrade
# ### Aiden Boyer
# #### Date: 2024-07-08
#
# In the operation of the Radium EDM experiment's new 60 kV Heinzinger high voltage (HV) power supply (PSU), there could be a production of X-rays when there's a discharge between two components at different potentials.
#
# Discharges in air are not expected to produce X-rays as electrons are apparently not accelerated to high enough energies to radiate Bremsstrahlung.
#
# X-rays COULD be produced by a short burst of electrons striking one of the electrodes, while under vacuum. The resulting X-ray spectrum has a sharp and a broadband component. (**Sharp**: Spectral features with small wavelength range, **Broadband**: Spectral features with large wavelength range).

# %% [markdown]
# ### Kramer's Formula
#
# The high energy part of the continuous Bremsstrahlung spectrum is approximated by Kramer's Formula:
#
# ## $\frac{d^2 N_{\gamma}}{dtdu}=\left[ \frac{I_0}{e} \right] \left[ \frac{2\alpha}{3\sqrt{3\ell}} \right] \left[ \frac{eV_0}{m_e c^2} \right] \left[ \frac{2Z(1-u)}{u} \right]$
#
# Where the parameters involved have the following definitions:
#
# * $N_\gamma$: The maximum number of X-rays
# * $E$: The energy of the X-rays
# * $u$: The relative energy of the X-rays, defined as $u = \frac{E}{E_0}$
# * $E_0$: $E_0 = eV_0$
# * $V_0$: The potential between the HV electrodes
# * $e$: Elementary charge of an electron
# * $I$: Electron beam current
# * $\alpha$: Fine structure constant, $\alpha \approx \frac{1}{137}$
# * $\ell$: Thickness of the "target", in this case I think its the thickness of the electrode
# * $m_e$: electron mass
# * $c$: The speed of light, 299,792,458 m/s
# * $Z$: Atomic number of the target material

# %% [markdown]
# ### Assumption 1: Isotropic Angular Distribution of X-Rays
#
# We can assume that for X-Ray energies much less than 511 keV (annihilation radiation), the angular distribution of the X-rays is isotropic. In this case, the power spectrum is given by:
#
# ## $\frac{dP_b}{du} = \frac{d^2N_{\gamma}}{dtdu}E = P_b\left[2Z(1-u)\right]$
#
# Where $P_b$ is the un-attenuated Brehmsstrahlung power, given below by:
#
# ## $P_b = \int_{0}^{1} \frac{dP_b}{du}du =\left[ \frac{2\alpha}{3\sqrt{3}\ell} \right] \left[ \frac{eV_0}{m_e c^2} \right] ZP_0$
#
# where $P_0 = I_0 V_0$ is the electron beam power

# %% [markdown]
# ### More Assumptions
#
# The X-rays which reach the HV personnel are determined by the type and thickness of shielding between the electrodes and the personnel. We assume for this that:
#
# #### Assumption 2: Max Power
# We assume that the max power of the X-rays is generated when the HV is operated at the maximum voltage across the Niobium electrodes: 60 kV (aka, $V_0 = 60,000$ Volts)
#
# #### Assumption 3: Max Current
# We assume that we're operating at the maximum current output of the circuit: 1 mA
#
# #### Assumption 4: Characteristic X-ray power
# We assume that the Characteristic X-rays (**Characteristic X-rays**: X-rays emitted when outer-shell electrons fill a vacancy in the inner shell of an atom, releasing X-rays in a pattern that is "characteristic" to each element) are all emitted at the K-edge (**K-edge**: a sudden increase in X-ray absorption that occurrs when the energy of the X-rays is just above the binding energy of the innermost electron shell of the atoms interacting with the photons) energy with intensity that is a factor of 10 greater than the total un attenuated Brehmsstrahlung power ($P_c = 10P_b$ at $E_K$)
#
# #### Assumption 5: X-ray penetration through HV vacuum chamber
# We assume that to reach the personnel, X-rays must penetrate an equivalent thickness of 5mm Pyrex glass whose attenuation length varies with the energy of the incident X-ray
#
#
# ### Comments on these assumptions
# **Assumption 2** and **Assumption 3** are intuitive - we want to obtain an upper bound on the radiological hazard so it makes sense to run these calculations for the higher possible current and potential that we'd see in our setup
#
# **Assumption 4** is not intuitive to me - how do we intuit this is an assumption we could make?
#
# **Assumption 5** makes sense - X-rays that could be hazardous need to escape the vacuum chamber. Would it be possible for the X-rays to pass through the stainless steel that composes the chamber in addition to the Pyrex glass viewports?

# %% [markdown]
# ### X-ray power spectrum at the surface of the Pyrex glass
#
# At the outer surface of the glass, the power spectrum has the following form:
#
# ## $\frac{dP_a}{du}=\left[ \frac{dP_b}{du}+P_c\delta(u-u_K) \right] e^{-\frac{\Delta t}{t_0(E)}}$
#
# Where the parameters have the following definitions:
# * $P_a$: The attenuated X-ray power per unit relative energy
# * $\delta(x)$: Dirac delta function
# * $u_K$: $u_K = \frac{E_K}{eV_0}$ is the K-edge X-ray energy relative to the voltage between the HV electrodes
# * $\Delta t$: The thickness of the vacuum chamber viewports (5mm)
# * $t_0(E)$: Attenuation length for an X-ray of energy $E$
#
# We can utilize the algebraic expression for $\frac{dP_b}{du}$, but will still need to implement an integral to obtain the attenuated spectrum. The integration will be performed over u, which can range from 0 to 1.

# %% [markdown]
# ### Estimating the Absorbed Dose
#
# Once we know the attenuation, we can estimate the abosrbed dose ($M_{abs}$) with:
#
# ## $M_{abs} \leq \left< P \right> \left[ \left( \frac{I_{dis}}{I_{max}} \right)t_d \right] \left[ \frac{\Omega}{4\pi} \right] \left[ \frac{f_T}{m_T} \right] \left[ \omega_R \omega_T \right] $
#
# Where the parameters have the following definitions:
# * $\left<P\right> = \int_{0}^{1} (\frac{dP_a}{du})du$ is the average X-ray power
# * $\frac{I_{dis}}{I_0}$: the discharge current relative to the maximum current
# * $t_d$: the average duration of the discharge
# * $\Omega$: The solid angle covered by the personnel
# * $f_T$: fraction of X-rays absorbed by tissue
# * $m_T$: mass of tissue
# * $\omega_R$: Radiation weighting factor
# * $\omega_T$: Tissue weighting factor

# %% [markdown]
# ### Assmuption 6: Information from previous electrode conditioning
#
# Experience with previous electrode conditioning implies that:
# * $t_d \leq 1$; discharges only occur during electrode conditioning
# * X-rays only exit the vacuum chamber through one of the viewports, limiting $\frac{\Omega}{4\pi} \approx \frac{1}{6}$
# * X-rays are completely absorbed when incident on a person: $f_T = 1$
# * The tissue weighting factor is assumed to be $\omega_T=0.2$, the mass of the tissue is assumed to be $m_T=50$ kg, and that radiation weigthing factor is assumed to be $\omega_R=1.0$.

# %% [markdown]
# ### Open Questions For The Upgrade to 60 kV
#
# I have a few questions on the nature of some of these parameters. Certain parameters change with the upgrade to 60 kV, for example, $E_0$ will change and thus $u_K$ should change by definition. However, its unclear if:
# * Does $N_\gamma$ change as we increase the potential? Are more X-rays produced?
# * Does E (energy of the X-rays themselves) change as we increase the potential?
# * How do $I_0$, $V_0$, and $P_0$ change? I think these would just scale up to the potential and current output for the new HV PSU, but I'm not sure.

# %% [markdown]
# ## Calculations for estimating the dose

# %%
#Import required libraries [Block 1]

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.integrate import quad

# %%
#We will attempt to reproduce the results from JTS's hazard mitigation document. Here, we define constants [Block 2]
V_0 = 30000 #[V]
I_0 = 0.001 #[A]
E_K = 19000 # [eV]
alpha = 1/137 #fine structure
ell = 6 #assuming unitless, but I think this should have units of [mm]
m_e = 0.511 #[MeV/c^2]
Z = 41 #Atomic number for Niobium
c = 1 #units of c, using to manipulate mass units
q_e = 1 #units of e, using to manually enforce eV
E_0 = q_e*V_0 # [eV]
delta_t = 5 #thickness of vacuum viewports, units [mm]
u_K = E_K / (q_e*V_0) #rleative energy of K-edge X-rays

# %%
#Calculate the characteristic X-ray power, which is 10*P_b [Block 3]
prefactor = (2*alpha)/(3*np.sqrt(3)*ell) #Unitless
scaled_E=(E_0)/(m_e*1E6) #Unitless
scaled_P = Z*I_0*V_0 # [A*V] = [W]
P_c = 10*prefactor * scaled_E * scaled_P #should be units of [A*V]=[W]

print("P_c = ", P_c)
print("The intensity of the characteristic X-rays is: ", 1000*P_c, "mW") #This correctly reproduces the characteristic
#X-rays for Niobium @ 30 kV
# Out:
# P_c =  0.3381284876765846
# The intensity of the characteristic X-rays is:  338.1284876765846 mW

# %%
#Read in the mass attenuation information with no cuts and get it into an attenuation length [Block 4]
colnames=["Photon Energy [MeV]","Total Attenuation W/ Coherent Scattering [cm^2/g]","Total Attenuation W/O Coherent Scattering [cm^2/g]"]
df = pd.read_csv("Mass Attenuation Data.txt", names=colnames, sep = " ") #read data file, delimiter is a space
pyrex_dens = 2.23 #density of Pyrex [g/cm^3]
df["Coherent Attenuation Length [mm]"] = 10 / (df["Total Attenuation W/ Coherent Scattering [cm^2/g]"] * pyrex_dens) #multiply by 10 to get to mm from cm
df["Incoherent Attenuation Length  [mm]"] = 10 / (df["Total Attenuation W/O Coherent Scattering [cm^2/g]"] * pyrex_dens)
df["Energy [eV]"] = df["Photon Energy [MeV]"] * 1E6
df

plt.plot(df["Energy [eV]"]/1000,df["Total Attenuation W/ Coherent Scattering [cm^2/g]"])
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Mass attenuation coef. (cm^2/g)")
plt.xlabel("X-Ray Energy (keV)")
plt.savefig("Mass Attenuation vs X-Ray Energy.png")
plt.show()

#Check: Plot the attenuation length vs the x-ray energy and see if it matches Figure 4 from the HV Mitigation Doc
plt.plot(df["Energy [eV]"]/1000,df["Coherent Attenuation Length [mm]"])
plt.xlabel("X-Ray energy (keV)")
plt.ylabel("Attenuation length in PYREX 7740 (mm)")
plt.yscale("log")
plt.savefig("Attenuation Length vs X-Ray Energy.png")

# %%
#Read in the mass attenuation information with cuts and get it into an attenuation length [Block 5]
colnames=["Photon Energy [MeV]","Total Attenuation W/ Coherent Scattering [cm^2/g]","Total Attenuation W/O Coherent Scattering [cm^2/g]"]
df2 = pd.read_csv("Mass Attenuation Data With Cuts.txt", names=colnames, sep = " ") #read data file, delimiter is a space
pyrex_dens = 2.23 #density of Pyrex [g/cm^3]
df2["Coherent Attenuation Length [mm]"] = 10 / (df2["Total Attenuation W/ Coherent Scattering [cm^2/g]"] * pyrex_dens) #multiply by 10 to get to mm from cm
df2["Incoherent Attenuation Length  [mm]"] = 10 / (df2["Total Attenuation W/O Coherent Scattering [cm^2/g]"] * pyrex_dens)
df2["Energy [eV]"] = df2["Photon Energy [MeV]"] * 1E6
df2

plt.plot(df2["Energy [eV]"]/1000,df2["Total Attenuation W/ Coherent Scattering [cm^2/g]"])
plt.yscale("log")
plt.xscale("log")
plt.ylabel("Mass attenuation coef. (cm^2/g)")
plt.xlabel("X-Ray Energy (keV)")
plt.savefig("Mass Attenuation vs X-Ray Energy With Data Cuts.png")
plt.show()

#Check: Plot the attenuation length vs the x-ray energy and see if it matches Figure 4 from the HV Mitigation Doc
plt.plot(df2["Energy [eV]"]/1000,df2["Coherent Attenuation Length [mm]"])
plt.xlabel("X-Ray energy (keV)")
plt.ylabel("Attenuation length in PYREX 7740 (mm)")
plt.yscale("log")
plt.savefig("Attenuation Length vs X-Ray Energy With Data Cuts.png")

# %%
#We'll check that the attenuation length of the glass at the characteristic X-ray concentrated at 19 keV is 1.71mm [Block 6]
df.iloc[73] #checks row 73 of the dataframe, which is where I know that E=19 keV happens. This is the uncut dataset
#We see that the attenuation length matches, suggesting that we're calculating it correctly, and also implying
#That the scattering we are interested in is coherent
# Out:
# Photon Energy [MeV]                                       0.019000
# Total Attenuation W/ Coherent Scattering [cm^2/g]         2.616000
# Total Attenuation W/O Coherent Scattering [cm^2/g]        2.453000
# Coherent Attenuation Length [mm]                          1.714184
# Incoherent Attenuation Length  [mm]                       1.828090
# Energy [eV]                                           19000.000000
# Name: 73, dtype: float64

# %%
#We'll check that the attenuation length of the glass at the characteristic X-ray concentrated at 19 keV is 1.71mm [Block 7]
df2.iloc[35] #checks row 36 of the dataframe, which is where I know that E=19 keV happens. This is the cut dataset
#We see that the attenuation length matches, suggesting that we're calculating it correctly, and also implying
#That the scattering we are interested in is coherent
# Out:
# Photon Energy [MeV]                                       0.019000
# Total Attenuation W/ Coherent Scattering [cm^2/g]         2.616000
# Total Attenuation W/O Coherent Scattering [cm^2/g]        2.453000
# Coherent Attenuation Length [mm]                          1.714184
# Incoherent Attenuation Length  [mm]                       1.828090
# Energy [eV]                                           19000.000000
# Name: 35, dtype: float64

# %%
#Define the delta function for integrating. This suggestion comes from Nick [Block 8]
def delta(x,alpha=0.0008): #alpha=0.0008
    alpha_sq = alpha*alpha
    return (1 / np.pi) * alpha / (alpha_sq + x*x)

# %%
#Define the expression in the integrand as a function of the relative X-ray energy and the attenuation length [Block 9]
def integrand(u, t0_E_value, dbg = False): #plot the integrand
    prefactor = (2*alpha)/(3*np.sqrt(3)*ell) #First bracketed term in P_b, which is Eq'n (3) in HV Mitigation Doc
    scaled_E=(E_0)/(m_e*1E6) #Second bracketed term in P_b, which is Eq'n (3) in HV Mitigation Doc
    scaled_P = Z*I_0*V_0 #Z*P_0 term in P_b, which is Eq'n (3) in HV Mitigation Doc
    energy_factor = 2*Z*(1-u) #The bracketed term in the dPb_du expression, Equation (2) in the HV Mitigation Doc
    dPb_du = prefactor*scaled_E*scaled_P*energy_factor #Algebraical expression of Equation (2) in code
    if dbg: 
        print(f"prf={prefactor}, scE={scaled_E}, scP={scaled_P}, ef={energy_factor}, dPb_du={dPb_du}")
        delta_P_c = P_c*delta(u-u_K)
        exp_factor = np.exp(-delta_t / t0_E_value)
        #print(f"P_c*delta(u-u_K)={delta_P_c}, exp_factor={exp_factor}")
    return (dPb_du + P_c*delta(u-u_K)) * np.exp(-delta_t / t0_E_value) #delta function + thing

# %%
#Set up ranges and variables for integrating [Block 10]
#Grab the min and max energies
E_min = df2["Energy [eV]"].min()
E_max = df2["Energy [eV]"].max()

#Scale them to relative energies
u_min = E_min/E_0
u_max = E_max/E_0

#Prepare lists for running the integral
energy_values = df2["Energy [eV]"]
dPa_values = []
errors = []

# %%
#Loop over energies to pick out attenuation lengths [Block 11]
i=0
for i in range(len(energy_values)): #for all the energy values we have
    E = df2["Energy [eV]"][i] #Pick out a single value
    u=E/E_0 #Construct the relative energy
    t0_E = df2["Coherent Attenuation Length [mm]"][i] #Pick out the associated Attenuation Length
    #print(t0_E)
    #Print for diagnostic purposes
    print("E (keV): ", E/1000, ", Atten. Length (mm)", t0_E, ", Val of integrand", integrand(u_K, t0_E), ", exp. term", np.exp(-delta_t / t0_E))
    
    #Integrate the differential term to get the power
    dPa_regular, err = quad(integrand, u_min, u_max, args=(t0_E))#u_min, u, args=(t0_E))
    dPa_values.append(dPa_regular)
    errors.append(err)
    i+=1
# Out:
# E (keV):  9.286 , Atten. Length (mm) 0.2145600446284893 , Val of integrand 1.0269040954050121e-08 , exp. term 7.575626262795153e-11
# E (keV):  9.582 , Atten. Length (mm) 0.23514970806163743 , Val of integrand 7.901072765369083e-08 , exp. term 5.828740445521201e-10
# E (keV):  9.878 , Atten. Length (mm) 0.25698022537165766 , Val of integrand 4.810078722195621e-07 , exp. term 3.5484675596318047e-09
# E (keV):  10.0 , Atten. Length (mm) 0.2664471142445292 , Val of integrand 9.60240367882977e-07 , exp. term 7.083837898865639e-09
# E (keV):  10.17 , Atten. Length (mm) 0.2802690582959641 , Val of integrand 2.422689671170194e-06 , exp. term 1.7872546795405348e-08
# E (keV):  10.47 , Atten. Length (mm) 0.30484737816012414 , Val of integrand 1.0208578103045633e-05 , exp. term 7.531021906454319e-08
# E (keV):  10.77 , Atten. Length (mm) 0.33070095374155056 , Val of integrand 3.67992828550516e-05 , exp. term 2.7147385514983864e-07
# E (keV):  11.06 , Atten. Length (mm) 0.35817132050602446 , Val of integrand 0.00011734031140350296 , exp. term 8.656371600138035e-07
# E (keV):  11.36 , Atten. Length (mm) 0.3869115558874397 , Val of integrand 0.000330970205374265 , exp. term 2.4416170811424244e-06
# E (keV):  11.65 , Atten. Length (mm) 0.41714464490562103 , Val of integrand 0.0008444017237399633 , exp. term 6.229278764528668e-06
# E (keV):  11.95 , Atten. Length (mm) 0.44892431001455857 , Val of integrand 0.0019726702432299485 , exp. term 1.455268565907636e-05
# E (keV):  12.25 , Atten. Length (mm) 0.4822351793456744 , Val of integrand 0.004257738191707014 , exp. term 3.140997626704388e-05
# E (keV):  12.54 , Atten. Length (mm) 0.5171612193213501 , Val of integrand 0.008575918305755725 , exp. term 6.326584170359682e-05
# E (keV):  12.84 , Atten. Length (mm) 0.5536862492573683 , Val of integrand 0.01622799891311665 , exp. term 0.0001197163934869021
# E (keV):  13.13 , Atten. Length (mm) 0.5917530922057833 , Val of integrand 0.029010362053878996 , exp. term 0.00021401381263542774
# E (keV):  13.43 , Atten. Length (mm) 0.6315922440472431 , Val of integrand 0.04943324029457931 , exp. term 0.00036467646307611644
# E (keV):  13.72 , Atten. Length (mm) 0.672914905872663 , Val of integrand 0.08037981426995382 , exp. term 0.0005929740028370391
# E (keV):  14.02 , Atten. Length (mm) 0.715999510256335 , Val of integrand 0.1256974813456982 , exp. term 0.0009272892620747721
# E (keV):  14.32 , Atten. Length (mm) 0.7609545109002929 , Val of integrand 0.18988679491761667 , exp. term 0.001400823501408419
# E (keV):  14.61 , Atten. Length (mm) 0.8075463592176169 , Val of integrand 0.27741874468656474 , exp. term 0.0020465598856242964
# E (keV):  14.91 , Atten. Length (mm) 0.8559467327229292 , Val of integrand 0.3937192446911841 , exp. term 0.002904526200252456
# E (keV):  15.0 , Atten. Length (mm) 0.8714156495793678 , Val of integrand 0.43673782766508595 , exp. term 0.0032218807696066574
# E (keV):  15.2 , Atten. Length (mm) 0.9061032395909125 , Val of integrand 0.5440211247529244 , exp. term 0.004013325819455581
# E (keV):  15.5 , Atten. Length (mm) 0.958184814687057 , Val of integrand 0.7343039754454843 , exp. term 0.005417071084000029
# E (keV):  15.800000000000002 , Atten. Length (mm) 1.0120300006173382 , Val of integrand 0.9692844107472909 , exp. term 0.007150557165982515
# E (keV):  16.09 , Atten. Length (mm) 1.067691650651292 , Val of integrand 1.2540368144384948 , exp. term 0.009251218559241775
# E (keV):  16.39 , Atten. Length (mm) 1.1252960935346112 , Val of integrand 1.5937548919620268 , exp. term 0.011757370011504243
# E (keV):  16.68 , Atten. Length (mm) 1.1844439864594363 , Val of integrand 1.9896879141675239 , exp. term 0.01467822758208861
# E (keV):  16.98 , Atten. Length (mm) 1.2456402590931739 , Val of integrand 2.4482360836173114 , exp. term 0.018061006529786143
# E (keV):  17.28 , Atten. Length (mm) 1.3089039500103403 , Val of integrand 2.972424053011013 , exp. term 0.02192802017336695
# E (keV):  17.57 , Atten. Length (mm) 1.3738679328233536 , Val of integrand 3.5608803349283664 , exp. term 0.026269150843453215
# E (keV):  17.87 , Atten. Length (mm) 1.4405091335481612 , Val of integrand 4.21383348288402 , exp. term 0.031086084613764747
# E (keV):  18.16 , Atten. Length (mm) 1.5093587791098708 , Val of integrand 4.936728176804107 , exp. term 0.03641898770861158
# E (keV):  18.46 , Atten. Length (mm) 1.5800933519152311 , Val of integrand 5.725888874937699 , exp. term 0.04224074510260533
# E (keV):  18.76 , Atten. Length (mm) 1.6528952940418082 , Val of integrand 6.5822247716679785 , exp. term 0.04855806405972329
# E (keV):  19.0 , Atten. Length (mm) 1.7141838427887715 , Val of integrand 7.334049356058141 , exp. term 0.054104387316205024
# E (keV):  19.05 , Atten. Length (mm) 1.727390189805634 , Val of integrand 7.49943586254775 , exp. term 0.055324468497768994
# E (keV):  19.35 , Atten. Length (mm) 1.8038233840448212 , Val of integrand 8.478027353936502 , exp. term 0.06254368540018931
# E (keV):  19.64 , Atten. Length (mm) 1.881789732578861 , Val of integrand 9.509799558215779 , exp. term 0.07015522443575754
# E (keV):  19.94 , Atten. Length (mm) 1.9616382032963369 , Val of integrand 10.59601301164629 , exp. term 0.07816838477042752
# E (keV):  20.0 , Atten. Length (mm) 1.978951867932668 , Val of integrand 10.834958441331333 , exp. term 0.07993112121348646
# E (keV):  20.24 , Atten. Length (mm) 2.043894682194816 , Val of integrand 11.74065728213805 , exp. term 0.08661259804788589
# E (keV):  20.53 , Atten. Length (mm) 2.128289004620515 , Val of integrand 12.936629702439667 , exp. term 0.09543546682147107
# E (keV):  20.83 , Atten. Length (mm) 2.213378545279085 , Val of integrand 14.159387042736103 , exp. term 0.10445593198625536
# E (keV):  21.12 , Atten. Length (mm) 2.300823464718022 , Val of integrand 15.428752272813284 , exp. term 0.11382023057760439
# E (keV):  21.42 , Atten. Length (mm) 2.390354441756624 , Val of integrand 16.73709978386052 , exp. term 0.1234721073301681
# E (keV):  21.71 , Atten. Length (mm) 2.4816297358801473 , Val of integrand 18.07559705135699 , exp. term 0.1333464033795247
# E (keV):  22.01 , Atten. Length (mm) 2.5742278603532873 , Val of integrand 19.43426605267888 , exp. term 0.14336950934912382
# E (keV):  22.31 , Atten. Length (mm) 2.6692291266282298 , Val of integrand 20.825283457946163 , exp. term 0.15363125436942376
# E (keV):  22.6 , Atten. Length (mm) 2.766381821551774 , Val of integrand 22.241341779760592 , exp. term 0.16407773000467388
# E (keV):  22.9 , Atten. Length (mm) 2.8653705640481957 , Val of integrand 23.674364578963985 , exp. term 0.17464935514611205
# E (keV):  23.19 , Atten. Length (mm) 2.965810140698033 , Val of integrand 25.115565651027257 , exp. term 0.18528131263887576
# E (keV):  23.49 , Atten. Length (mm) 3.0672400360707432 , Val of integrand 26.555524347245125 , exp. term 0.19590410493780605
# E (keV):  23.79 , Atten. Length (mm) 3.171361338568194 , Val of integrand 28.01549638450537 , exp. term 0.20667453866954913
# E (keV):  24.08 , Atten. Length (mm) 3.27560623282354 , Val of integrand 29.45703612994568 , exp. term 0.21730899460685218
# E (keV):  24.38 , Atten. Length (mm) 3.381828757719024 , Val of integrand 30.90375814693084 , exp. term 0.2279816809422925
# E (keV):  24.67 , Atten. Length (mm) 3.489731465163756 , Val of integrand 32.34931348979736 , exp. term 0.2386457605469457
# E (keV):  24.97 , Atten. Length (mm) 3.6018513515947195 , Val of integrand 33.82475055268696 , exp. term 0.24953028210328385
# E (keV):  25.27 , Atten. Length (mm) 3.712172957562439 , Val of integrand 35.249375027551665 , exp. term 0.2600399515404763
# E (keV):  25.56 , Atten. Length (mm) 3.82619874806777 , Val of integrand 36.693065981886086 , exp. term 0.2706902772699712
# E (keV):  25.86 , Atten. Length (mm) 3.9405140006462447 , Val of integrand 38.110803538784715 , exp. term 0.28114914087549253
# E (keV):  26.15 , Atten. Length (mm) 4.0545252556378175 , Val of integrand 39.495146833594184 , exp. term 0.29136164997717917
# E (keV):  26.45 , Atten. Length (mm) 4.17144644905621 , Val of integrand 40.88416398275876 , exp. term 0.3016086388067776
# E (keV):  26.75 , Atten. Length (mm) 4.291200892569786 , Val of integrand 42.274869142235765 , exp. term 0.31186808034282826
# E (keV):  27.04 , Atten. Length (mm) 4.4136859574167575 , Val of integrand 43.66416747011206 , exp. term 0.3221171434701557
# E (keV):  27.34 , Atten. Length (mm) 4.533722508073426 , Val of integrand 44.99364688122741 , exp. term 0.33192491343402813
# E (keV):  27.63 , Atten. Length (mm) 4.656599099413734 , Val of integrand 46.322268166279926 , exp. term 0.3417263528726183
# E (keV):  27.93 , Atten. Length (mm) 4.780708883513248 , Val of integrand 47.631666344383284 , exp. term 0.3513859805543871
# E (keV):  28.22 , Atten. Length (mm) 4.905704991505772 , Val of integrand 48.9180426798695 , exp. term 0.3608757726338549
# E (keV):  28.52 , Atten. Length (mm) 5.0323251405402605 , Val of integrand 50.18877014522589 , exp. term 0.3702501206401429
# E (keV):  28.82 , Atten. Length (mm) 5.15971111809392 , Val of integrand 51.43512471990712 , exp. term 0.3794446661590077
# E (keV):  29.11 , Atten. Length (mm) 5.288095439546494 , Val of integrand 52.65956004428871 , exp. term 0.3884775100652547
# E (keV):  29.41 , Atten. Length (mm) 5.417790180905432 , Val of integrand 53.86507449750661 , exp. term 0.3973707718536156
# E (keV):  29.7 , Atten. Length (mm) 5.548508949190084 , Val of integrand 55.04906064679165 , exp. term 0.40610521609962075
# E (keV):  30.0 , Atten. Length (mm) 5.680649775443914 , Val of integrand 56.21517843706683 , exp. term 0.4147078427685086

# %%
#Plot the results and save them [Block 12] 
plt.figure(figsize=(12,8))    

plt.plot(energy_values/1000, dPa_values, marker="o", linestyle="--")
#plt.plot(energy_values/1000, errors, "ro", linestyle="--")
plt.yscale("log")
plt.xlabel("Energy (keV)")
plt.xlim(0,31)
plt.ylim(10**(-3),10**(0))
plt.ylabel("Attenuated X-ray power (W)")
plt.savefig("Aiden Attenuated X-Ray Spectrum With Data Cuts.png")
